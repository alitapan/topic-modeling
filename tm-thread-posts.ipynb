# %% [markdown]
# ### 1. Data Preprocessing

# %% [markdown]
# Topic modeling only the original forum post, not including the replies.

# %%
import pandas as pd
d = pd.read_csv("data/covid-19_discussions/2020-07-29.csv")

# %% [markdown]
# Store the thread texts into a dictionary format where the key is
# is the forum post header and the value is forum post text.

# %%
d_texts = dict()
i = 0

while(i < d.size - 1):
    try:
        err = False
        # get thread_text 
        text = d["thread_text"][i].lower()
        
        # get thread_name
        header  = d["thread_name"][i]
        
        # get number of replies so we can quickly skip to the next post
        replies = int(d["replies"][i])
        
    except:
        err = True
        
    # if there is no replies skip to the next post
    if(replies == 0):
        i += 1
        d_texts[header] = text
    # if there are replies update index variable
    elif(err == False):
        i += replies
        d_texts[header] = text
    else:
        i += 1

# %% [markdown]
# Create a pandas data frame of the data

# %%
df = pd.DataFrame(list(d_texts.values()),columns = ['Text'], index = list(d_texts.keys()) ) 
df.head()
# Out:
#                                                                                                  Text
# About the COVID-19 Discussions category             i’ve created this category to be a lightning r...
# POLL: Just a few questions about your experienc...  all your answers will remain anonymous. please...
# Have you lowered your rates due to COVID-19?        have you changed your rate to get more busines...
# No sales at all, Maybe (COVID-19) is the reason?    first of all, maybe some of you know me very w...
# Support for SMBs and Freelancers during the spr...  \n\na letter to the fiverr community & beyond....

# %% [markdown]
# ### 2. Tokenizing the data and converting it into a document-term matrix.

# %% [markdown]
# We declare function to pull out nouns and adjactives from a string of text
# Source: https://github.com/adashofdata/nlp-in-python-tutorial

# %%
import nltk
from nltk import word_tokenize, pos_tag, punkt
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# %%
def nouns_adj(text):
    '''Given a string of text, tokenize the text and pull out only the nouns and adjectives.'''
    is_noun_adj = lambda pos: pos[:2] == 'NN' or pos[:2] == 'JJ'
    tokenized = word_tokenize(text)
    nouns_adj = [word for (word, pos) in pos_tag(tokenized) if is_noun_adj(pos)] 
    return ' '.join(nouns_adj)

# %% [markdown]
# Apply the nouns_adj function to the transcripts to filter only on nouns

# %%
data_clean = pd.DataFrame(df.Text.apply(nouns_adj))
data_clean.head()
# Out:
#                                                                                                  Text
# About the COVID-19 Discussions category             i category lightning rod covid-19 discussions ...
# POLL: Just a few questions about your experienc...  answers anonymous answer polls page voters vot...
# Have you lowered your rates due to COVID-19?                         rate more business crisis voters
# No sales at all, Maybe (COVID-19) is the reason?    i active user forum reason i busy other projec...
# Support for SMBs and Freelancers during the spr...  letter fiverr community worst thing covid-19 a...

# %% [markdown]
# Create the document-term matrix

# %%
add_stop_words = ['like', 'im', 'know', 'just', 'dont', 'thats', 'right', 'people',
                  'youre', 'got', 'gonna', 'time', 'think', 'yeah', 'said']
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

cvn = CountVectorizer(stop_words=stop_words, max_df=.8)
#cvn = CountVectorizer(stop_words=stop_words)
data_cvn = cvn.fit_transform(data_clean.Text)
data_dtm = pd.DataFrame(data_cvn.toarray(), columns=cvn.get_feature_names())
data_dtm.index = data_clean.index
data_dtm.head()
# Out:
#                                                     10  19  60  80k  ability  \
# About the COVID-19 Discussions category              0   1   0    0        0
# POLL: Just a few questions about your experienc...   0   0   0    0        0
# Have you lowered your rates due to COVID-19?         0   0   0    0        0
# No sales at all, Maybe (COVID-19) is the reason?     0   0   0    0        0
# Support for SMBs and Freelancers during the spr...   0   1   0    0        1
#
#                                                     able  absense  accessible  \
# About the COVID-19 Discussions category                0        0           0
# POLL: Just a few questions about your experienc...     0        0           0
# Have you lowered your rates due to COVID-19?           0        0           0
# No sales at all, Maybe (COVID-19) is the reason?       0        0           0
# Support for SMBs and Freelancers during the spr...     1        0           0
#
#                                                     account  actions  ...  \
# About the COVID-19 Discussions category                   0        0  ...
# POLL: Just a few questions about your experienc...        0        0  ...
# Have you lowered your rates due to COVID-19?              0        0  ...
# No sales at all, Maybe (COVID-19) is the reason?          0        0  ...
# Support for SMBs and Freelancers during the spr...        0        0  ...
#
#                                                     write  wrong  www  xox  \
# About the COVID-19 Discussions category                 0      0    0    0
# POLL: Just a few questions about your experienc...      0      0    0    0
# Have you lowered your rates due to COVID-19?            0      0    0    0
# No sales at all, Maybe (COVID-19) is the reason?        0      0    0    0
# Support for SMBs and Freelancers during the spr...      0      0    0    0
#
#                                                     year  years  yeeei  \
# About the COVID-19 Discussions category                0      0      0
# POLL: Just a few questions about your experienc...     0      0      0
# Have you lowered your rates due to COVID-19?           0      0      0
# No sales at all, Maybe (COVID-19) is the reason?       0      0      0
# Support for SMBs and Freelancers during the spr...     0      0      0
#
#                                                     yellow  yes  yesterday
# About the COVID-19 Discussions category                  0    0          0
# POLL: Just a few questions about your experienc...       0    0          0
# Have you lowered your rates due to COVID-19?             0    0          0
# No sales at all, Maybe (COVID-19) is the reason?         0    0          0
# Support for SMBs and Freelancers during the spr...       0    0          0
#
# [5 rows x 1302 columns]

# %% [markdown]
# ### 3. Latent Dirichlet Allocation (LDA) for Topic Modeling

# %%
from gensim import matutils, models
import scipy.sparse

# %% [markdown]
# Convert the document-term matrix into term-document-matrix by taking the transpose

# %%
# One of the required inputs is a term-document matrix
tdm = data_dtm.transpose()
tdm.head()
# Out:
#          About the COVID-19 Discussions category  \
# 10                                             0
# 19                                             1
# 60                                             0
# 80k                                            0
# ability                                        0
#
#          POLL: Just a few questions about your experiences with covid-19  \
# 10                                                       0
# 19                                                       0
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          Have you lowered your rates due to COVID-19?  \
# 10                                                  0
# 19                                                  0
# 60                                                  0
# 80k                                                 0
# ability                                             0
#
#          No sales at all, Maybe (COVID-19) is the reason?  \
# 10                                                      0
# 19                                                      0
# 60                                                      0
# 80k                                                     0
# ability                                                 0
#
#          Support for SMBs and Freelancers during the spread of COVID-19  \
# 10                                                       0
# 19                                                       1
# 60                                                       0
# 80k                                                      0
# ability                                                  1
#
#          How are YOU doing?  \
# 10                        0
# 19                        1
# 60                        0
# 80k                       0
# ability                   0
#
#          How can we be more productive during Covid-19 time?  \
# 10                                                       0
# 19                                                       0
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          Has the order been reduced due to coronavirus?  \
# 10                                                    0
# 19                                                    0
# 60                                                    0
# 80k                                                   0
# ability                                               0
#
#          Q: How does the COVID-19 pandemic impact Rotary’s fight to end polio?  \
# 10                                                       0
# 19                                                       2
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          Is Corona Virus effects number of new customers?  ...  \
# 10                                                      0  ...
# 19                                                      0  ...
# 60                                                      0  ...
# 80k                                                     0  ...
# ability                                                 0  ...
#
#          COVID-19 Disease Advise  Has Corona affected work on Fiver?  \
# 10                             0                                   0
# 19                             0                                   0
# 60                             0                                   0
# 80k                            0                                   0
# ability                        0                                   0
#
#          Take advantage of this time!  \
# 10                                  0
# 19                                  0
# 60                                  0
# 80k                                 0
# ability                             0
#
#          What it feels like to be under lockdown during COVID-19  \
# 10                                                       0
# 19                                                       1
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          COVID - 19 & Fiverr  \
# 10                         0
# 19                         1
# 60                         0
# 80k                        0
# ability                    0
#
#          Fiverr Fee removal or reduced percentage due to Corona  \
# 10                                                       0
# 19                                                       0
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          ️ Lets Stay Beside Each Other From The Heart In Particluar ️🙋🏻‍♂️  \
# 10                                                       0
# 19                                                       0
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          Have stopped constructions due to covid-19?  \
# 10                                                 0
# 19                                                 0
# 60                                                 0
# 80k                                                0
# ability                                            0
#
#          Staying at Home? But do consider your health is very important  \
# 10                                                       0
# 19                                                       0
# 60                                                       0
# 80k                                                      0
# ability                                                  0
#
#          No order due to corona virus
# 10                                  0
# 19                                  0
# 60                                  0
# 80k                                 0
# ability                             0
#
# [5 rows x 142 columns]

# %% [markdown]
# Put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus

# %% [markdown]
# Topic Modeling with LDA

# %%
lda = models.LdaModel(corpus=corpus, num_topics=4, id2word=id2word, passes=80)
lda.print_topics()
# Out:
# [(0,
#   '0.028*"fiverr" + 0.014*"safe" + 0.013*"pandemic" + 0.012*"virus" + 0.011*"19" + 0.011*"covid" + 0.011*"home" + 0.011*"world" + 0.010*"corona" + 0.010*"new"'),
#  (1,
#   '0.020*"orders" + 0.015*"situation" + 0.013*"new" + 0.012*"work" + 0.011*"covid" + 0.011*"fiverr" + 0.010*"virus" + 0.009*"day" + 0.009*"order" + 0.008*"business"'),
#  (2,
#   '0.024*"covid" + 0.023*"19" + 0.021*"freelancers" + 0.014*"fiverr" + 0.010*"pandemic" + 0.008*"fund" + 0.008*"games" + 0.006*"country" + 0.006*"world" + 0.006*"fortnite"'),
#  (3,
#   '0.021*"fiverr" + 0.009*"covid" + 0.008*"days" + 0.008*"19" + 0.008*"market" + 0.007*"health" + 0.007*"home" + 0.007*"day" + 0.007*"work" + 0.006*"tough"')]

# %% [markdown]
# ## Topic Breakdown:
#
# <div>Topic 0 ==> Fiverr Site</div>
# <div>Topic 1 ==> Orders</div>
# <div>Topic 2 ==> Covid</div>
# <div>Topic 3 ==> ??</div>

# %% [markdown]
# ### 4. Topic Identification for each post

# %%
# Identify which topics each transcript contains
corpus_transformed = lda[corpus]

# %% [markdown]
# Here we can see the probability distribution of each topic by post

# %%
for i in range(len(corpus_transformed)):
    print(corpus_transformed[i])
# Out:
# [(0, 0.028703079), (1, 0.027950961), (2, 0.028231679), (3, 0.91511434)]
# [(0, 0.022935238), (1, 0.022744667), (2, 0.9315193), (3, 0.022800753)]
# [(0, 0.05192743), (1, 0.39869097), (2, 0.49496728), (3, 0.05441429)]
# [(2, 0.9861826)]
# [(3, 0.9950377)]
# [(2, 0.97838277)]
# [(0, 0.08473), (1, 0.084903516), (2, 0.084744796), (3, 0.7456217)]
# [(0, 0.08551452), (1, 0.08338307), (2, 0.7442263), (3, 0.086876154)]
# [(2, 0.98173994)]
# [(0, 0.028879076), (1, 0.028140623), (2, 0.9125659), (3, 0.030414483)]
# [(0, 0.92782605), (1, 0.023042463), (2, 0.024506552), (3, 0.024624897)]
# [(0, 0.011317018), (1, 0.01098319), (2, 0.011792805), (3, 0.965907)]
# [(0, 0.014164531), (1, 0.014079771), (2, 0.95741993), (3, 0.014335729)]
# [(0, 0.9865091)]
# [(0, 0.9446608), (1, 0.018360946), (2, 0.018277382), (3, 0.0187009)]
# [(0, 0.010192294), (1, 0.010085794), (2, 0.010251194), (3, 0.96947074)]
# [(0, 0.022302164), (1, 0.020942483), (2, 0.9349934), (3, 0.021762)]
# [(0, 0.013608292), (1, 0.013559159), (2, 0.9594521), (3, 0.0133804595)]
# [(3, 0.9818491)]
# [(0, 0.990548)]
# [(0, 0.748025), (1, 0.0834247), (2, 0.0841338), (3, 0.08441653)]
# [(0, 0.8682092), (1, 0.042434536), (2, 0.04555255), (3, 0.043803748)]
# [(0, 0.016607782), (1, 0.015748069), (2, 0.9512229), (3, 0.016421225)]
# [(0, 0.028472899), (1, 0.02818673), (2, 0.02979637), (3, 0.913544)]
# [(0, 0.036183875), (1, 0.03585501), (2, 0.037217084), (3, 0.89074403)]
# [(0, 0.016665077), (1, 0.016039984), (2, 0.950969), (3, 0.01632596)]
# [(3, 0.9850593)]
# [(0, 0.018380472), (1, 0.018089997), (2, 0.9451225), (3, 0.018407049)]
# [(0, 0.12521482), (1, 0.12531656), (2, 0.6242705), (3, 0.12519811)]
# [(2, 0.98678786)]
# [(0, 0.051501807), (1, 0.050461996), (2, 0.054914627), (3, 0.8431215)]
# [(0, 0.021128627), (1, 0.021027913), (2, 0.93634534), (3, 0.021498144)]
# [(1, 0.9730393)]
# [(0, 0.6809122), (1, 0.01571788), (2, 0.28681928), (3, 0.016550636)]
# [(0, 0.043321952), (1, 0.042030606), (2, 0.8714441), (3, 0.043203346)]
# [(0, 0.74192107), (1, 0.08428592), (2, 0.08832415), (3, 0.08546891)]
# [(0, 0.47884282), (1, 0.50529003)]
# [(0, 0.94076186), (1, 0.019687923), (2, 0.019813288), (3, 0.019736955)]
# [(0, 0.8734236), (1, 0.04184424), (2, 0.041772157), (3, 0.04296009)]
# [(3, 0.9790545)]
# [(0, 0.012166443), (1, 0.012028158), (2, 0.9632325), (3, 0.0125729395)]
# [(1, 0.99586666)]
# [(0, 0.032244686), (1, 0.03150291), (2, 0.03253048), (3, 0.9037219)]
# [(0, 0.032145377), (1, 0.90402395), (2, 0.031624198), (3, 0.032206476)]
# [(0, 0.95705736), (1, 0.014056099), (2, 0.01438272), (3, 0.014503846)]
# [(0, 0.023990493), (1, 0.022990474), (2, 0.023902737), (3, 0.9291163)]
# [(0, 0.029535932), (1, 0.028301252), (2, 0.913925), (3, 0.028237889)]
# [(0, 0.9845549)]
# [(0, 0.91340053), (1, 0.027799625), (2, 0.029601268), (3, 0.029198546)]
# [(0, 0.022096852), (1, 0.32765815), (2, 0.02234586), (3, 0.62789917)]
# [(0, 0.97483015)]
# [(0, 0.06403785), (1, 0.8023622), (2, 0.06724505), (3, 0.066354886)]
# [(0, 0.028911257), (1, 0.91459835), (2, 0.027919732), (3, 0.028570594)]
# [(0, 0.084360406), (1, 0.083454385), (2, 0.7487751), (3, 0.08341006)]
# [(0, 0.0128715215), (1, 0.013160239), (2, 0.012811103), (3, 0.96115714)]
# [(0, 0.06821142), (1, 0.06521876), (2, 0.06485153), (3, 0.8017183)]
# [(3, 0.97829527)]
# [(0, 0.022165895), (1, 0.021184778), (2, 0.935218), (3, 0.021431373)]
# [(0, 0.03173861), (1, 0.031703416), (2, 0.90490603), (3, 0.03165195)]
# [(0, 0.959843), (1, 0.0132506285), (2, 0.0134577835), (3, 0.013448588)]
# [(0, 0.036522932), (1, 0.035759978), (2, 0.037446395), (3, 0.8902707)]
# [(0, 0.015239791), (1, 0.014831995), (2, 0.015195529), (3, 0.9547327)]
# [(0, 0.084262736), (1, 0.08340067), (2, 0.086851574), (3, 0.745485)]
# [(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)]
# [(0, 0.84589386), (1, 0.050065592), (2, 0.053174876), (3, 0.050865732)]
# [(0, 0.06708084), (1, 0.064388245), (2, 0.800341), (3, 0.068189904)]
# [(0, 0.010176106), (1, 0.96950674), (2, 0.010222764), (3, 0.01009442)]
# [(2, 0.9847358)]
# [(0, 0.017018406), (1, 0.9476335), (2, 0.017810335), (3, 0.017537775)]
# [(2, 0.9811044)]
# [(3, 0.9907509)]
# [(0, 0.012401474), (1, 0.012183842), (2, 0.012406659), (3, 0.963008)]
# [(0, 0.94716036), (1, 0.017419627), (2, 0.017758247), (3, 0.017661756)]
# [(0, 0.010196503), (2, 0.0102512045), (3, 0.96961606)]
# [(0, 0.12504391), (1, 0.1250641), (2, 0.1271068), (3, 0.62278515)]
# [(0, 0.052889694), (1, 0.051769778), (2, 0.05210459), (3, 0.84323597)]
# [(0, 0.94511545), (1, 0.018025788), (2, 0.018576635), (3, 0.018282095)]
# [(0, 0.9842264)]
# [(0, 0.0363362), (1, 0.03603891), (2, 0.887892), (3, 0.039732937)]
# [(0, 0.019766856), (1, 0.019452376), (2, 0.94063884), (3, 0.02014189)]
# [(0, 0.052073), (1, 0.050160978), (2, 0.8463664), (3, 0.051399596)]
# [(3, 0.9731863)]
# [(0, 0.011709862), (1, 0.011767053), (2, 0.011962498), (3, 0.9645606)]
# [(0, 0.8994372), (1, 0.03164091), (2, 0.03526612), (3, 0.033655744)]
# [(0, 0.051978156), (1, 0.050162464), (2, 0.8470192), (3, 0.05084015)]
# [(0, 0.038760703), (1, 0.037776466), (2, 0.037443355), (3, 0.88601947)]
# [(2, 0.98406035)]
# [(0, 0.027957175), (1, 0.027917532), (2, 0.028924303), (3, 0.91520095)]
# [(0, 0.98972565)]
# [(0, 0.023634715), (1, 0.023514394), (2, 0.023514682), (3, 0.9293362)]
# [(2, 0.97445744)]
# [(2, 0.975175)]
# [(0, 0.029366052), (1, 0.027891712), (2, 0.913449), (3, 0.02929321)]
# [(0, 0.03761218), (1, 0.03628347), (2, 0.8890163), (3, 0.037088092)]
# [(0, 0.017241366), (1, 0.016854052), (2, 0.017424086), (3, 0.9484805)]
# [(2, 0.98547775)]
# [(0, 0.017536335), (1, 0.017024595), (2, 0.948273), (3, 0.017166022)]
# [(0, 0.12509553), (1, 0.12513973), (2, 0.6246766), (3, 0.12508816)]
# [(3, 0.97594607)]
# [(0, 0.024823302), (1, 0.925681), (2, 0.02382293), (3, 0.025672786)]
# [(2, 0.9746059)]
# [(0, 0.016844956), (1, 0.015973195), (2, 0.016571501), (3, 0.95061034)]
# [(0, 0.015023414), (1, 0.015005663), (2, 0.9547495), (3, 0.015221345)]
# [(0, 0.9757605)]
# [(0, 0.0362364), (1, 0.036227178), (2, 0.037844755), (3, 0.88969165)]
# [(2, 0.982223)]
# [(0, 0.035662036), (1, 0.031359006), (2, 0.0338982), (3, 0.89908075)]
# [(0, 0.043578386), (1, 0.04269357), (2, 0.8717837), (3, 0.041944355)]
# [(0, 0.95932883), (1, 0.01329798), (2, 0.013735792), (3, 0.013637426)]
# [(0, 0.0116727585), (1, 0.0115043055), (2, 0.011713733), (3, 0.9651092)]
# [(0, 0.9942536)]
# [(0, 0.023034573), (1, 0.022840878), (2, 0.9311637), (3, 0.022960829)]
# [(2, 0.9734433)]
# [(0, 0.8914641), (1, 0.036103845), (2, 0.03630311), (3, 0.03612895)]
# [(0, 0.9596884), (1, 0.013374171), (2, 0.013458612), (3, 0.013478824)]
# [(3, 0.97313774)]
# [(0, 0.9282441), (1, 0.02304125), (2, 0.024971241), (3, 0.023743438)]
# [(0, 0.018531194), (1, 0.01817491), (2, 0.019539982), (3, 0.94375396)]
# [(0, 0.044740718), (1, 0.041915953), (2, 0.044024926), (3, 0.8693184)]
# [(0, 0.08343004), (1, 0.08981513), (2, 0.08340742), (3, 0.7433474)]
# [(0, 0.12520939), (1, 0.12530814), (2, 0.12518889), (3, 0.6242936)]
# [(0, 0.9219408), (1, 0.025562964), (2, 0.025605537), (3, 0.026890691)]
# [(0, 0.03880501), (1, 0.8827077), (2, 0.039349757), (3, 0.039137516)]
# [(0, 0.028647995), (1, 0.027826913), (2, 0.91348356), (3, 0.030041568)]
# [(0, 0.019605327), (1, 0.019360919), (2, 0.020294074), (3, 0.9407397)]
# [(3, 0.99242157)]
# [(0, 0.014753705), (1, 0.014006851), (2, 0.95684475), (3, 0.014394736)]
# [(0, 0.92763233), (1, 0.023747476), (2, 0.023356192), (3, 0.025264058)]
# [(0, 0.036414314), (1, 0.035926178), (2, 0.03682057), (3, 0.890839)]
# [(0, 0.84510624), (1, 0.051768284), (2, 0.051689282), (3, 0.05143623)]
# [(2, 0.9819319)]
# [(0, 0.39017636), (1, 0.025898393), (2, 0.5582666), (3, 0.025658684)]
# [(0, 0.87368506), (1, 0.041731976), (2, 0.042082004), (3, 0.042500924)]
# [(0, 0.902245), (1, 0.031657197), (2, 0.03302581), (3, 0.03307197)]
# [(0, 0.01640554), (1, 0.29037586), (2, 0.6766921), (3, 0.016526511)]
# [(1, 0.9937633)]
# [(0, 0.9867265)]
# [(0, 0.55007863), (1, 0.018086188), (2, 0.018410526), (3, 0.4134246)]
# [(2, 0.9855504)]
# [(0, 0.86831474), (1, 0.042065013), (2, 0.044239428), (3, 0.04538082)]
# [(0, 0.012097572), (1, 0.011611469), (2, 0.9639273), (3, 0.012363639)]
# [(0, 0.8489929), (1, 0.050035957), (2, 0.0504511), (3, 0.050520115)]

# %%
# We select the highest probability of each topic for each post
topics_by_post = []
for i in range(len(corpus_transformed)):
    max = -1
    for j in range(len(corpus_transformed[i])):
        if corpus_transformed[i][j][1] > max:
            max = corpus_transformed[i][j][1]
            topic_number = j
    topics_by_post. append(topic_number)

# %% [markdown]
# Finally we can see each forum post with their assigned topic

# %%
list(zip(topics_by_post, data_dtm.index))
# Out:
# [(3, 'About the COVID-19 Discussions category'),
#  (2, 'POLL: Just a few questions about your experiences with covid-19'),
#  (2, 'Have you lowered your rates due to COVID-19?'),
#  (0, 'No sales at all, Maybe (COVID-19) is the reason?'),
#  (0, 'Support for SMBs and Freelancers during the spread of COVID-19'),
#  (0, 'How are YOU doing?'),
#  (3, 'How can we be more productive during Covid-19 time?'),
#  (2, 'Has the order been reduced due to coronavirus?'),
#  (0, 'Q: How does the COVID-19 pandemic impact Rotary’s fight to end polio?'),
#  (2, 'Is Corona Virus effects number of new customers?'),
#  (0,
#   'Any idea about which services are likely to get more affected during COVID?'),
#  (3, 'Did Quarantine due to COVID-19 Impacts your selling?'),
#  (2, 'Since COVID-19 started I’m getting few jobs from the Spanish industry'),
#  (0, 'Blessed by Fiverr in Covid-19 times'),
#  (0, 'Time for doing something for other'),
#  (3, 'Isolation stress, can’t buy masks or sanitizer either!'),
#  (2, 'Is Corona Virus Pandemic affecting orders in fiverr?'),
#  (2, 'Where is the origin of the virus?'),
#  (0, 'Coronavirus (COVID-19) Impacts On Freelancing!'),
#  (0, 'Anybody else in self-isolation?'),
#  (0, 'What we do in covid-19?'),
#  (0, 'How it’s going?'),
#  (2, 'COVID-19 Impact on Bussiness'),
#  (3, 'Covid 19 For BD'),
#  (3, 'Stayy homE stayy safe'),
#  (2, 'Video Game Friend Codes? (Off Topic)'),
#  (0, 'Life in corona season with online jobs'),
#  (2, 'Corona virus has attacked on gig’s'),
#  (2, 'Hay all Covid19'),
#  (0, 'Mental Breakdown'),
#  (3, 'Our Ex-health minister died in Corona'),
#  (2, 'Response time decreased during pandemic'),
#  (0, 'Covid 19 and Stress'),
#  (0, 'Does Fiverr Sales also affected due to pandemic?'),
#  (2, 'Due to COVID 19? POLL'),
#  (0, 'How are you guys in this situation?'),
#  (1, 'Conspiracy Theory… Fiverr “bugs”'),
#  (0, 'Did you guys also decrease the order because of corona virus?'),
#  (0, 'What are the positive impacts of the COVID-19 crisis?'),
#  (0,
#   'These Days I See New Buyers Mostly Who Just Joined in Mar/Apr 2020; Is It For COVID-19 that more people are buying service in Fiverr?'),
#  (2, 'Coronavirus Outbreak | Free Courses From Fiverr'),
#  (0, 'Annihilation by COVID-19 and probable remady'),
#  (3,
#   'I think due to covid-19, number of selling and order decrease. What you think?'),
#  (1, 'How is everyone doing in quarantine?'),
#  (0, 'About 36 % patients are affected with their kidney by COVID-19'),
#  (3, 'Can we discuss how to still get orders in this COVID-19 times'),
#  (2, 'Has Fiverr been affected by Corona virus?'),
#  (0, 'My sales have been through the roof these days. Something SURPRISING!'),
#  (0, 'Has anyone else joined to feel more productive duing COVID?'),
#  (3, 'Hellow everyone?'),
#  (0, 'COVID-19 Experience, How To Kill It’s Effect on you'),
#  (1, 'When coronavirus going to end?'),
#  (1, 'When the vaccine will be develop during this virus?'),
#  (2, 'How prepared is Europe for COVID-19?'),
#  (3,
#   'Fiverr should release earnings earlier(around 5 days) during COVID times'),
#  (3, 'Isn’t everyone safe?'),
#  (0, 'What game are you playing?'),
#  (2, 'Covid 19 related problems'),
#  (2, 'COVID-19 v/s your country'),
#  (0,
#   'Can Fiverr Freelancers Apply for Unemployment Benefits under the CARES Act? If so, how?'),
#  (3, 'How you are utilizing the quarantine period?'),
#  (3, 'Effect of Covid-19 on fiverr'),
#  (3, 'Who is New Here Due to Covid - 19'),
#  (0, 'How long does it take to make a vaccine?'),
#  (0, 'What is your best game to play in this Coronavirus Quarantine?'),
#  (2, 'No work getting'),
#  (1, 'Email addresses or First Responders in Orange County California'),
#  (0, 'Let’s stop this!'),
#  (1, 'Let’s remember and respect who lost from this coronavirus'),
#  (0, 'My gig went down, because of corona virus'),
#  (0, 'Fiverr statistics in times of Corona'),
#  (3, 'Want to published my first gig but worry about Covid-19'),
#  (0, 'What do you do if feeling exhausted in these quarantine days?'),
#  (2, 'Would Fiverr be a good plan B?'),
#  (3, 'When will the disease stop?'),
#  (3, 'Is anyone learning any new topic in this quarantine period?'),
#  (0, 'Hi, FIVERR Friends how is all you businees Situation after CORONA,,,'),
#  (0, 'Covid 19 reminder for today'),
#  (2, 'Orders are increased during now! Agree?'),
#  (2, 'Poll: How is the COVID-19 impacting your sales?'),
#  (2, 'Fiverr vs. Covid'),
#  (0, 'Covid-19 in kerala'),
#  (3,
#   'Can Fiverr fasten the pending fund clearance during this period to help sellers'),
#  (0, 'Is It Too Boring?'),
#  (2, 'Lack of work in this pandemic period in qurantime'),
#  (3, 'Feel like crap and a lone'),
#  (0, 'Fear not COVID19'),
#  (3, 'Therapy in difficult times'),
#  (0, 'How are you handling open orders that go dark in the time of COVID-19?'),
#  (3, 'Because of this Pandemic Payment Clearance should be less than 14 days'),
#  (0, 'Helping is Blessing'),
#  (0, 'Reduced fees due to COVID-19'),
#  (2, 'Covid19, fiverr with us'),
#  (2, 'Saty Safe and Stay Home Everyone'),
#  (3, 'I’m new and I would love to know more about stats'),
#  (0, 'Are You Learning Anything New During Your Covid-19 Downtime?'),
#  (2, 'Work distribution'),
#  (2, 'Correct handwashing technique'),
#  (0, 'Let the virus beat by playing a game!'),
#  (1, 'COVID-19 Report from Bangladesh'),
#  (0, 'Helping out organizations affected by COVID-19 or fighting against it'),
#  (3, 'Coronavirus disease (COVID-19)'),
#  (2, 'Stay Home Stay Safe'),
#  (0, 'Support the world'),
#  (3, 'About Covid 19 . how are guys?'),
#  (0, '#Stay Safe #Let us Fight Together'),
#  (3, 'Does COVID-19 effect on orders?'),
#  (2, 'I made illustration in this lockdown'),
#  (0, 'Corona Impact on Fiverr'),
#  (3, 'Post Covid-19 Pandemic Freelance Career'),
#  (0, 'My Review Regarding Covid-19'),
#  (2, 'Is Paranoia now a thing?'),
#  (0, 'Due To covid-19 is hurting Fiver Gigs as well'),
#  (0, 'Gigs to offer during this weird time'),
#  (0, 'Update about Corona'),
#  (0, 'These Are Gonne Be A Rough Few Weeks'),
#  (0, 'Is COVID19 affect the fiverr?'),
#  (3, 'Everything will be alright'),
#  (3, 'Health is Wealth'),
#  (3, 'Covid-19 Sales Drop'),
#  (3, 'Stay safe, everyone! Don’t forget to wash your hands'),
#  (0,
#   'What you think, in current the scope of freelancers are increase or decrease?'),
#  (1, 'Feeling alone and lost'),
#  (2, 'COVID-19 Effect On Freelancing'),
#  (3, 'Coronavirus Problems'),
#  (0, 'Freelancers Relief Fund (US Only)'),
#  (2, 'HELP! Each other during (COVID 19)'),
#  (0,
#   'Do you think COVID-19 will impact on Freelancing career across the world?'),
#  (3, 'How is COVID-19 affecting freelancing market?'),
#  (0, 'Hey, how are you?'),
#  (0, 'Are you discovering price gouging due to the COVID-19?'),
#  (2, 'What will be then effect of Covid 19 on Fiverr Market?'),
#  (0, 'COVID-19 Disease Advise'),
#  (0, 'Has Corona affected work on Fiver?'),
#  (2, 'Take advantage of this time!'),
#  (0, 'What it feels like to be under lockdown during COVID-19'),
#  (0, 'COVID - 19 & Fiverr'),
#  (0, 'Fiverr Fee removal or reduced percentage due to Corona'),
#  (0, '️ Lets Stay Beside Each Other From The Heart In Particluar ️🙋🏻\u200d♂️'),
#  (0, 'Have stopped constructions due to covid-19?'),
#  (2, 'Staying at Home? But do consider your health is very important'),
#  (0, 'No order due to corona virus')]
